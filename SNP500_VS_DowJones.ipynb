# %%
import pandas as pd
import numpy as np 
from pandas import Series,DataFrame
from pandas_datareader import data
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import datetime as dt

# %%
# python_yahoo_url = 'https://pypi.python.org/pypi/yahoo-finance/1.1.4'
# pandas_yahoo_url = 'http://www.learndatasci.com/python-finance-part-yahoo-finance-api-pandas-matplotlib/'

# %%
# Define the instruments to download. We would like to see Apple, Microsoft and the S&P500 index.
tickers = ['DOW','SPY','GOOG']

# Define which online source one should use
data_source = 'google'

# We would like all available data from 01/01/2000 until 12/31/2016.
start_date = '2010-01-01'
end_date = '2016-12-31'

# User pandas_reader.data.DataReader to load the desired data. As simple as that.
panel_data = data.DataReader(tickers, data_source, start_date, end_date)


# Getting just the adjusted closing prices. This will return a Pandas DataFrame
# The index in this DataFrame is the major index of the panel_data.
close = panel_data.loc['Close']

#day_high= panel_data.loc['High']
#day_low= panel_data.loc['Low']
#day_open= panel_data.loc['Open']

# Getting all weekdays between 01/01/2000 and 12/31/2016
all_weekdays = pd.date_range(start=start_date, end=end_date, freq='B')

# How do we align the existing prices in adj_close with our new set of dates?
# All we need to do is reindex close using all_weekdays as the new index
#close = close.reindex(all_weekdays)

close.head(10)
# Out:
#               DOW    GOOG     SPY
# Date
# 2010-01-04  29.18  313.06  113.33
# 2010-01-05  30.48  311.68  113.63
# 2010-01-06  31.02  303.83  113.71
# 2010-01-07  31.04  296.75  114.19
# 2010-01-08  31.15  300.71  114.57
# 2010-01-11  30.76  300.25  114.73
# 2010-01-12  30.86  294.94  113.66
# 2010-01-13  30.75  293.25  114.62
# 2010-01-14  30.53  294.63  114.93
# 2010-01-15  29.99  289.71  113.64

# %%
close.describe()
# Out:
#                DOW         GOOG          SPY
# count  1762.000000  1761.000000  1761.000000
# mean     39.797741   460.513691   164.704651
# std       9.687550   173.762527    37.067717
# min      21.510000   217.820000   102.200000
# 25%      31.077500   299.350000   131.210000
# 50%      37.730000   438.060000   165.310000
# 75%      49.732500   579.180000   201.990000
# max      59.080000   813.110000   227.760000

# %%
close_df = close.reset_index()

# %%
close_df.head()
# Out:
#         Date    DOW     SPY
# 0 2010-01-04  29.18  113.33
# 1 2010-01-05  30.48  113.63
# 2 2010-01-06  31.02  113.71
# 3 2010-01-07  31.04  114.19
# 4 2010-01-08  31.15  114.57

# %%
sns.set_style("whitegrid")
g = sns.lmplot(x='SPY',
              y='DOW',
              data=close,
              aspect=2)
#g= (g.set_axis_labels("Date","Dow").set(xlim=(0,10),ylim=(0,100)))
plt.title('SNP_v_DOW')
plt.show(g)

# %%
sns.set_style("whitegrid")
g = sns.lmplot(x='SPY',
              y='GOOG',
              data=close,
              aspect=2)
#g= (g.set_axis_labels("Date","Dow").set(xlim=(0,10),ylim=(0,100)))
plt.title('SNP_v_GOOG')
plt.show(g)

# %%
sns.set_style("whitegrid")
g = sns.lmplot(x='GOOG',
              y='DOW',
              data=close,
              aspect=2)
#g= (g.set_axis_labels("Date","Dow").set(xlim=(0,10),ylim=(0,100)))
plt.title('DOW_v_GOOG')
plt.show(g)

# %%
close.plot(kind='scatter',x='DOW',y='SPY')

# %%
close.plot(kind='scatter',x='DOW',y='GOOG')

# %%
close.plot(kind='scatter',x='SPY',y='GOOG')

# %%
#plt.hist(close['SPY'],normed=True,alpha=0.5,bins=20)
#plt.hist(close['GOOG'],normed=True,color='y',alpha=0.5,bins=20)
plt.hist(close['DOW'],normed=True,color='indianred',alpha=0.5,bins=20)
#plt.hist(close['SPY'])
# Out:
# (array([ 0.0027191 ,  0.00966792,  0.03081648,  0.03172285,  0.05438203,
#          0.04199501,  0.04803746,  0.03383771,  0.0202422 ,  0.02084644,
#          0.01087641,  0.01661673,  0.0175231 ,  0.0256804 ,  0.03353558,
#          0.04350562,  0.05951811,  0.02386767,  0.00211486,  0.00483396]),
#  array([ 21.51  ,  23.3885,  25.267 ,  27.1455,  29.024 ,  30.9025,
#          32.781 ,  34.6595,  36.538 ,  38.4165,  40.295 ,  42.1735,
#          44.052 ,  45.9305,  47.809 ,  49.6875,  51.566 ,  53.4445,
#          55.323 ,  57.2015,  59.08  ]),
#  <a list of 20 Patch objects>)

# %%
tips= sns.load_dataset('tips')

# %%
sns.set_style("whitegrid")
g = sns.lmplot(x="tip",
              y="total_bill",
              data=tips,
              aspect=2)
g= (g.set_axis_labels("Tip","Total bill(USD)").set(xlim=(0,10),ylim=(0,100)))
plt.title('title')
plt.show(g)
